# %%
import numpy as np
from pycalphad import Model, Database, calculate, equilibrium
import pycalphad.variables as v

import pstats, cProfile
#dbf = Database('2016-08-10-AlGdMgand18RLPSO-for 3d plot.tdb')
dbf = Database('alfe_sei.TDB')
models = {key: Model(dbf, ['AL', 'FE', 'VA'], key) for key in dbf.phases.keys()}

# %%
#cProfile.runctx("equilibrium(dbf, ['AL', 'GD', 'MG', 'VA'], 'LPSO18R', {v.T: 300, v.P: 101325, v.X('AL'): 0.05, v.X('GD'): 0.1})", globals(), locals(), "Profile.prof")
cProfile.runctx("equilibrium(dbf, ['AL', 'FE', 'VA'], ['B2_BCC', 'AL13FE4'], {v.T: 700, v.X('AL'): (0,1,0.02), v.P: 101325}, model=models)", globals(), locals(), "Profile.prof")
s = pstats.Stats("Profile.prof")
s.strip_dirs().sort_stats("time").print_stats()
# Out:
# Sun Jan  8 23:23:22 2017    Profile.prof
#
#          733416 function calls (679189 primitive calls) in 0.973 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        25    0.165    0.007    0.798    0.032 eqsolver.pyx:304(_solve_eq_at_conditions)
#       479    0.137    0.000    0.158    0.000 eqsolver.pyx:253(_build_multiphase_system)
#       958    0.089    0.000    0.120    0.000 eqsolver.pyx:135(_compute_constraints)
#      1437    0.030    0.000    0.058    0.000 linalg.py:296(solve)
#      5555    0.027    0.000    0.027    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      1213    0.024    0.000    0.091    0.000 dataset.py:461(_construct_dataarray)
#       479    0.024    0.000    0.040    0.000 eqsolver.pyx:217(_build_multiphase_gradient)
#       479    0.023    0.000    0.050    0.000 eqsolver.pyx:26(remove_degenerate_phases)
# ...
