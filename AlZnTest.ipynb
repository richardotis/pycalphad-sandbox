# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from pycalphad.plot.eqplot import eqplot
import pycalphad.variables as v
from xarray import open_dataset
import numpy as np

# %%
eq = open_dataset('alzn.cdf')

# %%
eqplot(eq)
